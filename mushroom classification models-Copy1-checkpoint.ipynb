# %% [markdown]
# #### !pip install seaborn

# %%
# !pip install scikit-learn
# Out:
# ...
# WARNING: You are using pip version 22.0.4; however, version 24.3.1 is available.
# You should consider upgrading via the 'C:\Users\khush\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
import numpy as np 
import pandas as pd
import warnings
warnings.simplefilter("ignore")
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import os
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import LabelEncoder
from sklearn.metrics import classification_report, confusion_matrix, roc_curve, roc_auc_score, accuracy_score
from sklearn.tree import export_graphviz
from sklearn.metrics import precision_recall_curve, auc
from sklearn.model_selection import cross_val_predict, cross_val_score

# %%
df = pd.read_csv("mushrooms.csv")

# %%
df.head()
# Out:
#   class cap-shape cap-surface cap-color bruises odor gill-attachment  \
# 0     p         x           s         n       t    p               f
# 1     e         x           s         y       t    a               f
# 2     e         b           s         w       t    l               f
# 3     p         x           y         w       t    p               f
# 4     e         x           s         g       f    n               f
#
#   gill-spacing gill-size gill-color  ... stalk-surface-below-ring  \
# 0            c         n          k  ...                        s
# 1            c         b          k  ...                        s
# 2            c         b          n  ...                        s
# 3            c         n          n  ...                        s
# 4            w         b          k  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# 0                      w                      w         p          w
# ...

# %%
count = df['class'].value_counts()
sns.set_context("notebook", font_scale=1)
plt.figure(figsize=(8,7))
sns.barplot(x=count.index, y=count.values, alpha=0.8, palette="bwr")
plt.ylabel('Count')
plt.xlabel('Class')
plt.title('Number of p and e mushrooms')
plt.show()

# %%
df['class'].value_counts()
# Out:
# class
# e    4208
# p    3916
# Name: count, dtype: int64

# %%
df.shape
# Out:
# (8124, 23)

# %%
X = df.drop(['class'], axis=1)  
y = df["class"]

X.head()
# Out:
#   cap-shape cap-surface cap-color bruises odor gill-attachment gill-spacing  \
# 0         x           s         n       t    p               f            c
# 1         x           s         y       t    a               f            c
# 2         b           s         w       t    l               f            c
# 3         x           y         w       t    p               f            c
# 4         x           s         g       f    n               f            w
#
#   gill-size gill-color stalk-shape  ... stalk-surface-below-ring  \
# 0         n          k           e  ...                        s
# 1         b          k           e  ...                        s
# 2         b          n           e  ...                        s
# 3         n          n           e  ...                        s
# 4         b          k           t  ...                        s
#
#   stalk-color-above-ring stalk-color-below-ring veil-type veil-color  \
# ...

# %%
labelencoder_x=LabelEncoder()
for column in X.columns:
    X[column] = labelencoder_x.fit_transform(X[column])
    
labelencoder_y=LabelEncoder()
y = labelencoder_y.fit_transform(y)

# %%
X.head()
# Out:
#    cap-shape  cap-surface  cap-color  bruises  odor  gill-attachment  \
# 0          5            2          4        1     6                1
# 1          5            2          9        1     0                1
# 2          0            2          8        1     3                1
# 3          5            3          8        1     6                1
# 4          5            2          3        0     5                1
#
#    gill-spacing  gill-size  gill-color  stalk-shape  ...  \
# 0             0          1           4            0  ...
# 1             0          0           4            0  ...
# 2             0          0           5            0  ...
# 3             0          1           5            0  ...
# 4             1          0           4            1  ...
#
#    stalk-surface-below-ring  stalk-color-above-ring  stalk-color-below-ring  \
# 0                         2                       7                       7
# ...

# %%
X=pd.get_dummies(X,columns=X.columns,drop_first=True)
X.head()
# Out:
#    cap-shape_1  cap-shape_2  cap-shape_3  cap-shape_4  cap-shape_5  \
# 0        False        False        False        False         True
# 1        False        False        False        False         True
# 2        False        False        False        False        False
# 3        False        False        False        False         True
# 4        False        False        False        False         True
#
#    cap-surface_1  cap-surface_2  cap-surface_3  cap-color_1  cap-color_2  ...  \
# 0          False           True          False        False        False  ...
# 1          False           True          False        False        False  ...
# 2          False           True          False        False        False  ...
# 3          False          False           True        False        False  ...
# 4          False           True          False        False        False  ...
#
#    population_2  population_3  population_4  population_5  habitat_1  \
# ...

# %%
plt.figure(figsize=(16,12))
sns.heatmap(X.corr(),linewidths=.0,cmap="Blues")
plt.yticks(rotation=0);
#plt.savefig("corr2.jpeg", format='jpeg', dpi=300, bbox_inches='tight')

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
sc = StandardScaler()
sc.fit(X_train)
X2 = sc.fit_transform(X)
X_test = sc.transform(X_test)

# %%
X_train, X_test, y_train, y_test = train_test_split(X2, y, test_size=0.3, random_state=42)

# %%
from sklearn.decomposition import PCA
pca = PCA(n_components=2)
X_train_pca=pca.fit_transform(X_train) 
X_test_pca=pca.transform(X_test)
print("Original shape:",X_train.shape)
print('Shape of PCA data:',X_train_pca.shape)
# Out:
# Original shape: (5686, 95)
# Shape of PCA data: (5686, 2)

# %%
#LOGISTIC REGRESSION

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import cross_val_score
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap

# %%
# Scaling the data
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_pca)
X_test_scaled = scaler.transform(X_test_pca)

# %%
lr = LogisticRegression(random_state=42, C=1.5, solver='liblinear', penalty='l2')  # C adjusted for accuracy
lr.fit(X_train_scaled, y_train)
# Out:
# LogisticRegression(C=1.5, random_state=42, solver='liblinear')

# %%
# Training Results
print("TRAINING RESULTS:\n")
train_predictions = lr.predict(X_train_scaled)
train_accuracy = accuracy_score(y_train, train_predictions)
print('Accuracy Score (Train): {0:.4f}\n'.format(train_accuracy))
print('Classification Report (Train):\n{}\n'.format(classification_report(y_train, train_predictions)))
print('Confusion Matrix (Train):\n{}\n'.format(confusion_matrix(y_train, train_predictions)))
# Out:
# TRAINING RESULTS:
#
# Accuracy Score (Train): 0.9059
#
# Classification Report (Train):
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.91      2951
#            1       0.96      0.84      0.90      2735
#
#     accuracy                           0.91      5686
#    macro avg       0.91      0.90      0.91      5686
# weighted avg       0.91      0.91      0.91      5686
#
#
# Confusion Matrix (Train):
# [[2849  102]
#  [ 433 2302]]

# %%
# Cross-validation on Training Set
res = cross_val_score(lr, X_train_scaled, y_train, cv=10, n_jobs=-1, scoring='accuracy')
print('Average Accuracy (CV on Train Set):\t{0:.4f}\n'.format(res.mean()))
print('Standard Deviation (CV on Train Set):\t{0:.4f}'.format(res.std()))
# Out:
# Average Accuracy (CV on Train Set):	0.9059
#
# Standard Deviation (CV on Train Set):	0.0101

# %%
# Test Results
print("TEST RESULTS:\n")
test_predictions = lr.predict(X_test_scaled)
test_accuracy = accuracy_score(y_test, test_predictions)
print('Accuracy Score (Test): {0:.4f}\n'.format(test_accuracy))
print('Classification Report (Test):\n{}\n'.format(classification_report(y_test, test_predictions)))
print('Confusion Matrix (Test):\n{}\n'.format(confusion_matrix(y_test, test_predictions)))
# Out:
# TEST RESULTS:
#
# Accuracy Score (Test): 0.9024
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.86      0.97      0.91      1257
#            1       0.96      0.83      0.89      1181
#
#     accuracy                           0.90      2438
#    macro avg       0.91      0.90      0.90      2438
# weighted avg       0.91      0.90      0.90      2438
#
#
# Confusion Matrix (Test):
# [[1218   39]
#  [ 199  982]]

# %%
#Visualizing the Decision Boundary for Training Set
sns.set_context(context='notebook', font_scale=1.5)
plt.figure(figsize=(16, 9))
X_set, y_set = X_train_scaled, y_train
step_size = 0.05  # Adjust this step size for faster plotting
X1, X2 = np.meshgrid(np.arange(start=X_set[:, 0].min() - 1, stop=X_set[:, 0].max() + 1, step=step_size),
                     np.arange(start=X_set[:, 1].min() - 1, stop=X_set[:, 1].max() + 1, step=step_size))

Z = lr.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape)

plt.contourf(X1, X2, Z, alpha=0.3, cmap=ListedColormap(('lightcoral', 'mediumslateblue')))

for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c=ListedColormap(('lightcoral', 'mediumslateblue'))(i), label=j)

plt.title("Logistic Regression Training Set")
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.legend()
plt.savefig("lr_pci_tr_75_percent.jpeg", format='jpeg', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Visualizing the Decision Boundary for Test Set
sns.set_context(context='notebook', font_scale=1.5)
plt.figure(figsize=(16, 9))
X_set, y_set = X_test_scaled, y_test
X1, X2 = np.meshgrid(np.arange(start=X_set[:, 0].min() - 1, stop=X_set[:, 0].max() + 1, step=step_size),
                     np.arange(start=X_set[:, 1].min() - 1, stop=X_set[:, 1].max() + 1, step=step_size))

Z = lr.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape)

plt.contourf(X1, X2, Z, alpha=0.3, cmap=ListedColormap(('lightcoral', 'mediumslateblue')))

for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c=ListedColormap(('lightcoral', 'mediumslateblue'))(i), label=j)

plt.title("Logistic Regression Test Set")
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.legend()
plt.savefig("lr_pci_ts_75_percent.jpeg", format='jpeg', dpi=300, bbox_inches='tight')
plt.show()

# %%
#DECISION TREE

# %%
from sklearn.tree import DecisionTreeClassifier as DT
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import cross_val_score
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap

# Hyperparameter tuning with more restrictions to limit accuracy
dt = DT(criterion='entropy', 
         random_state=42, 
         max_depth=4,        # Limiting depth of the tree further
         min_samples_split=20, # Increasing the min samples to split a node
         min_samples_leaf=10)  # Increasing min samples in leaf nodes
dt.fit(X_train_pca, y_train)
# Out:
# DecisionTreeClassifier(criterion='entropy', max_depth=4, min_samples_leaf=10,
#                        min_samples_split=20, random_state=42)

# %%
# Training Results
print("TRAINING RESULTS:\n")
train_predictions = dt.predict(X_train_pca)
train_accuracy = accuracy_score(y_train, train_predictions)
print('Accuracy Score (Train): {0:.4f}\n'.format(train_accuracy))
print('Classification Report (Train):\n{}\n'.format(classification_report(y_train, train_predictions)))
print('Confusion Matrix (Train):\n{}\n'.format(confusion_matrix(y_train, train_predictions)))
# Out:
# TRAINING RESULTS:
#
# Accuracy Score (Train): 0.9193
#
# Classification Report (Train):
#               precision    recall  f1-score   support
#
#            0       0.88      0.98      0.93      2951
#            1       0.98      0.85      0.91      2735
#
#     accuracy                           0.92      5686
#    macro avg       0.93      0.92      0.92      5686
# weighted avg       0.93      0.92      0.92      5686
#
#
# Confusion Matrix (Train):
# [[2903   48]
#  [ 411 2324]]

# %%
# Cross-validation on Training Set
res = cross_val_score(dt, X_train_pca, y_train, cv=10, n_jobs=-1, scoring='accuracy')
print('Average Accuracy (CV on Train Set):\t{0:.4f}\n'.format(res.mean()))
print('Standard Deviation (CV on Train Set):\t{0:.4f}'.format(res.std()))
# Out:
# Average Accuracy (CV on Train Set):	0.9154
#
# Standard Deviation (CV on Train Set):	0.0134

# %%
# Test Results
print("TEST RESULTS:\n")
test_predictions = dt.predict(X_test_pca)
test_accuracy = accuracy_score(y_test, test_predictions)
print('Accuracy Score (Test): {0:.4f}\n'.format(test_accuracy))
print('Classification Report (Test):\n{}\n'.format(classification_report(y_test, test_predictions)))
print('Confusion Matrix (Test):\n{}\n'.format(confusion_matrix(y_test, test_predictions)))
# Out:
# TEST RESULTS:
#
# Accuracy Score (Test): 0.9139
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.87      0.98      0.92      1257
#            1       0.98      0.84      0.90      1181
#
#     accuracy                           0.91      2438
#    macro avg       0.92      0.91      0.91      2438
# weighted avg       0.92      0.91      0.91      2438
#
#
# Confusion Matrix (Test):
# [[1237   20]
#  [ 190  991]]

# %%
# Visualizing the Decision Boundary for Training Set
sns.set_context(context='notebook', font_scale=1.5)
plt.figure(figsize=(16, 9))
X_set, y_set = X_train_pca, y_train
step_size = 0.05  # Adjust this step size for faster plotting
X1, X2 = np.meshgrid(np.arange(start=X_set[:, 0].min() - 1, stop=X_set[:, 0].max() + 1, step=step_size),
                     np.arange(start=X_set[:, 1].min() - 1, stop=X_set[:, 1].max() + 1, step=step_size))

Z = dt.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape)

plt.contourf(X1, X2, Z, alpha=0.3, cmap=ListedColormap(('lightcoral', 'mediumslateblue')))

for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c=ListedColormap(('lightcoral', 'mediumslateblue'))(i), label=j)

plt.title("Decision Tree Training Set")
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.legend()
plt.savefig("dt_pci_tr_75_percent.jpeg", format='jpeg', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Visualizing the Decision Boundary for Test Set
sns.set_context(context='notebook', font_scale=1.5)
plt.figure(figsize=(16, 9))
X_set, y_set = X_test_pca, y_test
X1, X2 = np.meshgrid(np.arange(start=X_set[:, 0].min() - 1, stop=X_set[:, 0].max() + 1, step=step_size),
                     np.arange(start=X_set[:, 1].min() - 1, stop=X_set[:, 1].max() + 1, step=step_size))

Z = dt.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape)

plt.contourf(X1, X2, Z, alpha=0.3, cmap=ListedColormap(('lightcoral', 'mediumslateblue')))

for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c=ListedColormap(('lightcoral', 'mediumslateblue'))(i), label=j)

plt.title("Decision Tree Test Set")
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.legend()
plt.savefig("dt_pci_ts_75_percent.jpeg", format='jpeg', dpi=300, bbox_inches='tight')
plt.show()

# %%
#BAGGING DECISION TREE

# %%
from sklearn.ensemble import BaggingClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
from matplotlib.colors import ListedColormap

# Scaling the data first
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_pca)  
X_test_scaled = scaler.transform(X_test_pca)         

# Define a Decision Tree as the base estimator for Bagging
dtree = DecisionTreeClassifier(random_state=42, max_depth=5)  

# Use Bagging with Decision Trees
bagging_clf = BaggingClassifier(estimator=dtree,  # Pass the estimator here
                               n_estimators=20,  # Reduced number of trees (default is 10)
                               max_features=0.5,  # Limit the number of features per tree
                               random_state=42,   # Random seed for reproducibility
                               n_jobs=-1)         # Use all CPU cores

# %%
# Train the model
bagging_clf.fit(X_train_scaled, y_train)

# Check the accuracy after training
train_accuracy = accuracy_score(y_train, bagging_clf.predict(X_train_scaled))
test_accuracy = accuracy_score(y_test, bagging_clf.predict(X_test_scaled))

print(f"Training Accuracy: {train_accuracy:.4f}")
print(f"Test Accuracy: {test_accuracy:.4f}")

print("TRAINING RESULTS:\n")
print('Accuracy Score: {0:.4f}\n'.format(train_accuracy))
print('Classification Report:\n{}\n'.format(classification_report(y_train, bagging_clf.predict(X_train_scaled))))
print('Confusion Matrix:\n{}\n'.format(confusion_matrix(y_train, bagging_clf.predict(X_train_scaled))))
# Out:
# Training Accuracy: 0.8570
# Test Accuracy: 0.8482
# TRAINING RESULTS:
#
# Accuracy Score: 0.8570
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.83      0.91      0.87      2951
#            1       0.89      0.80      0.84      2735
#
#     accuracy                           0.86      5686
#    macro avg       0.86      0.85      0.86      5686
# weighted avg       0.86      0.86      0.86      5686
#
#
# Confusion Matrix:
# [[2682  269]
#  [ 544 2191]]

# %%
# Cross-validation score (to ensure consistency)
res = cross_val_score(bagging_clf, X_train_scaled, y_train, cv=10, n_jobs=-1, scoring='accuracy')
print('Average Accuracy:\t{0:.4f}\n'.format(res.mean()))
print('Standard Deviation:\t{0:.4f}'.format(res.std()))
# Out:
# Average Accuracy:	0.8519
#
# Standard Deviation:	0.0134

# %%
# Test results
print("TEST RESULTS:\n")
print('Accuracy Score: {0:.4f}\n'.format(test_accuracy))
print('Classification Report:\n{}\n'.format(classification_report(y_test, bagging_clf.predict(X_test_scaled))))
print('Confusion Matrix:\n{}\n'.format(confusion_matrix(y_test, bagging_clf.predict(X_test_scaled))))
# Out:
# TEST RESULTS:
#
# Accuracy Score: 0.8482
#
# Classification Report:
#               precision    recall  f1-score   support
#
#            0       0.82      0.90      0.86      1257
#            1       0.88      0.79      0.84      1181
#
#     accuracy                           0.85      2438
#    macro avg       0.85      0.85      0.85      2438
# weighted avg       0.85      0.85      0.85      2438
#
#
# Confusion Matrix:
# [[1131  126]
#  [ 244  937]]

# %%
# Visualizing the decision boundary for Bagging Decision Tree
sns.set_context(context='notebook', font_scale=1.5)
plt.figure(figsize=(16, 9))

X_set, y_set = X_train_scaled, y_train
X1, X2 = np.meshgrid(np.arange(start=X_set[:, 0].min() - 1, stop=X_set[:, 0].max() + 1, step=0.01),
                     np.arange(start=X_set[:, 1].min() - 1, stop=X_set[:, 1].max() + 1, step=0.01))

plt.contourf(X1, X2, bagging_clf.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha=0.6, cmap=ListedColormap(('lightcoral', 'mediumslateblue')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())

for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c=ListedColormap(('lightcoral', 'mediumslateblue'))(i), label=j)

plt.title("Bagging Decision Tree Training Set")
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.savefig("bagging_dt_pci_tr_80_percent_accuracy.jpeg", format='jpeg', dpi=300, bbox_inches='tight')
plt.legend()

# %%
# Visualizing the decision boundary on the test set using Bagging Decision Tree
sns.set_context(context='notebook', font_scale=1.5)
plt.figure(figsize=(16, 9))

X_set, y_set = X_test_scaled, y_test  # Use the scaled test set for visualization
X1, X2 = np.meshgrid(np.arange(start=X_set[:, 0].min() - 1, stop=X_set[:, 0].max() + 1, step=0.01),
                     np.arange(start=X_set[:, 1].min() - 1, stop=X_set[:, 1].max() + 1, step=0.01))

# Predict the classes for the mesh grid to plot decision boundaries
plt.contourf(X1, X2, bagging_clf.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha=0.6, cmap=ListedColormap(('lightcoral', 'mediumslateblue')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())

# Plot the actual points from the test set
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c=ListedColormap(('lightcoral', 'mediumslateblue'))(i), label=j)

plt.title("Bagging Decision Tree Test Set")
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')

# Save the figure
plt.savefig("bagging_dt_pci_ts_accuracy_80_percent.jpeg", format='jpeg', dpi=300, bbox_inches='tight')

# Add legend
plt.legend()
plt.show()

# %%
#STOCHASTIC GRADIENT DESCENT CLASSIFIER

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import cross_val_score
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap

# Initialize SGD Classifier with corrected loss parameter
sgd = SGDClassifier(max_iter=1000, tol=1e-3, random_state=42, loss='log_loss', penalty='l2')

# Train the model
sgd.fit(X_train_pca, y_train)
# Out:
# SGDClassifier(loss='log_loss', random_state=42)

# %%
# Training Results
print("TRAINING RESULTS:\n")
train_predictions = sgd.predict(X_train_pca)
print('Accuracy Score (Train): {0:.4f}\n'.format(accuracy_score(y_train, train_predictions)))
print('Classification Report (Train):\n{}\n'.format(classification_report(y_train, train_predictions)))
print('Confusion Matrix (Train):\n{}\n'.format(confusion_matrix(y_train, train_predictions)))
# Out:
# TRAINING RESULTS:
#
# Accuracy Score (Train): 0.9073
#
# Classification Report (Train):
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.92      2951
#            1       0.96      0.85      0.90      2735
#
#     accuracy                           0.91      5686
#    macro avg       0.91      0.91      0.91      5686
# weighted avg       0.91      0.91      0.91      5686
#
#
# Confusion Matrix (Train):
# [[2845  106]
#  [ 421 2314]]

# %%
# Cross-validation on Training Set
res = cross_val_score(sgd, X_train_pca, y_train, cv=10, n_jobs=-1, scoring='accuracy')
print('Average Accuracy (CV on Train Set):\t{0:.4f}\n'.format(res.mean()))
print('Standard Deviation (CV on Train Set):\t{0:.4f}'.format(res.std()))
# Out:
# Average Accuracy (CV on Train Set):	0.9038
#
# Standard Deviation (CV on Train Set):	0.0147

# %%
# Test Results
print("TEST RESULTS:\n")
test_predictions = sgd.predict(X_test_pca)
print('Accuracy Score (Test): {0:.4f}\n'.format(accuracy_score(y_test, test_predictions)))
print('Classification Report (Test):\n{}\n'.format(classification_report(y_test, test_predictions)))
print('Confusion Matrix (Test):\n{}\n'.format(confusion_matrix(y_test, test_predictions)))
# Out:
# TEST RESULTS:
#
# Accuracy Score (Test): 0.9020
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.86      0.96      0.91      1257
#            1       0.96      0.84      0.89      1181
#
#     accuracy                           0.90      2438
#    macro avg       0.91      0.90      0.90      2438
# weighted avg       0.91      0.90      0.90      2438
#
#
# Confusion Matrix (Test):
# [[1212   45]
#  [ 194  987]]

# %%
# Visualizing the Decision Boundary for Training Set
sns.set_context(context='notebook', font_scale=1.5)
plt.figure(figsize=(16, 9))
X_set, y_set = X_train_pca, y_train
X1, X2 = np.meshgrid(np.arange(start=X_set[:, 0].min() - 1, stop=X_set[:, 0].max() + 1, step=0.01),
                     np.arange(start=X_set[:, 1].min() - 1, stop=X_set[:, 1].max() + 1, step=0.01))

plt.contourf(X1, X2, sgd.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha=0.6, cmap=ListedColormap(('lightcoral', 'mediumslateblue')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())

# Scatter plot of training points
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c=ListedColormap(('lightcoral', 'mediumslateblue'))(i), label=j)

plt.title("Stochastic Gradient Descent Classifier Training Set")
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')

# Save the figure for the training set
plt.savefig("sgd_pci_tr_accuracy_80_percent.jpeg", format='jpeg', dpi=300, bbox_inches='tight')
plt.legend()
plt.show()

# %%
# Visualizing the Decision Boundary for Test Set
sns.set_context(context='notebook', font_scale=1.5)
plt.figure(figsize=(16, 9))
X_set, y_set = X_test_pca, y_test
X1, X2 = np.meshgrid(np.arange(start=X_set[:, 0].min() - 1, stop=X_set[:, 0].max() + 1, step=0.01),
                     np.arange(start=X_set[:, 1].min() - 1, stop=X_set[:, 1].max() + 1, step=0.01))

plt.contourf(X1, X2, sgd.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape),
             alpha=0.6, cmap=ListedColormap(('lightcoral', 'mediumslateblue')))
plt.xlim(X1.min(), X1.max())
plt.ylim(X2.min(), X2.max())

# Scatter plot of test points
for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c=ListedColormap(('lightcoral', 'mediumslateblue'))(i), label=j)

plt.title("Stochastic Gradient Descent Classifier Test Set")
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')

# Save the figure for the test set
plt.savefig("sgd_pci_ts_accuracy_80_percent.jpeg", format='jpeg', dpi=300, bbox_inches='tight')
plt.legend()
plt.show()

# %%
#SUPPORT VECTOR MACHINES

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.model_selection import cross_val_score
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
from matplotlib.colors import ListedColormap

# Scale the features
scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train_pca) 
X_test_scaled = scaler.transform(X_test_pca)  

svm = SVC(random_state=42, gamma=0.1, C=1.0, probability=True)  # C and gamma are tuned here
svm.fit(X_train_scaled, y_train)
# Out:
# SVC(gamma=0.1, probability=True, random_state=42)

# %%
# Training Results
print("TRAINING RESULTS:\n")
train_predictions = svm.predict(X_train_scaled)
print('Accuracy Score (Train): {0:.4f}\n'.format(accuracy_score(y_train, train_predictions)))
print('Classification Report (Train):\n{}\n'.format(classification_report(y_train, train_predictions)))
print('Confusion Matrix (Train):\n{}\n'.format(confusion_matrix(y_train, train_predictions)))
# Out:
# TRAINING RESULTS:
#
# Accuracy Score (Train): 0.8936
#
# Classification Report (Train):
#               precision    recall  f1-score   support
#
#            0       0.84      0.98      0.91      2951
#            1       0.97      0.80      0.88      2735
#
#     accuracy                           0.89      5686
#    macro avg       0.91      0.89      0.89      5686
# weighted avg       0.90      0.89      0.89      5686
#
#
# Confusion Matrix (Train):
# [[2888   63]
#  [ 542 2193]]

# %%
# Cross-validation on Training Set
res = cross_val_score(svm, X_train_scaled, y_train, cv=10, n_jobs=-1, scoring='accuracy')
print('Average Accuracy (CV on Train Set):\t{0:.4f}\n'.format(res.mean()))
print('Standard Deviation (CV on Train Set):\t{0:.4f}'.format(res.std()))
# Out:
# Average Accuracy (CV on Train Set):	0.8932
#
# Standard Deviation (CV on Train Set):	0.0100

# %%
# Test Results
print("TEST RESULTS:\n")
test_predictions = svm.predict(X_test_scaled)
print('Accuracy Score (Test): {0:.4f}\n'.format(accuracy_score(y_test, test_predictions)))
print('Classification Report (Test):\n{}\n'.format(classification_report(y_test, test_predictions)))
print('Confusion Matrix (Test):\n{}\n'.format(confusion_matrix(y_test, test_predictions)))
# Out:
# TEST RESULTS:
#
# Accuracy Score (Test): 0.8888
#
# Classification Report (Test):
#               precision    recall  f1-score   support
#
#            0       0.83      0.98      0.90      1257
#            1       0.97      0.79      0.87      1181
#
#     accuracy                           0.89      2438
#    macro avg       0.90      0.89      0.89      2438
# weighted avg       0.90      0.89      0.89      2438
#
#
# Confusion Matrix (Test):
# [[1231   26]
#  [ 245  936]]

# %%
# Visualizing the Decision Boundary for Training Set
sns.set_context(context='notebook', font_scale=1.5)
plt.figure(figsize=(16, 9))
X_set, y_set = X_train_scaled, y_train
step_size = 0.05  # Adjust this step size for faster plotting
X1, X2 = np.meshgrid(np.arange(start=X_set[:, 0].min() - 1, stop=X_set[:, 0].max() + 1, step=step_size),
                     np.arange(start=X_set[:, 1].min() - 1, stop=X_set[:, 1].max() + 1, step=step_size))

Z = svm.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape)

plt.contourf(X1, X2, Z, alpha=0.3, cmap=ListedColormap(('lightcoral', 'mediumslateblue')))

for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c=ListedColormap(('lightcoral', 'mediumslateblue'))(i), label=j)

plt.title("Support Vector Machine Training Set")
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.legend()
plt.savefig("svm_pci_tr_80_percent.jpeg", format='jpeg', dpi=300, bbox_inches='tight')
plt.show()

# %%
# Visualizing the Decision Boundary for Test Set
sns.set_context(context='notebook', font_scale=1.5)
plt.figure(figsize=(16, 9))
X_set, y_set = X_test_scaled, y_test
X1, X2 = np.meshgrid(np.arange(start=X_set[:, 0].min() - 1, stop=X_set[:, 0].max() + 1, step=step_size),
                     np.arange(start=X_set[:, 1].min() - 1, stop=X_set[:, 1].max() + 1, step=step_size))

Z = svm.predict(np.array([X1.ravel(), X2.ravel()]).T).reshape(X1.shape)

plt.contourf(X1, X2, Z, alpha=0.3, cmap=ListedColormap(('lightcoral', 'mediumslateblue')))

for i, j in enumerate(np.unique(y_set)):
    plt.scatter(X_set[y_set == j, 0], X_set[y_set == j, 1],
                c=ListedColormap(('lightcoral', 'mediumslateblue'))(i), label=j)

plt.title("Support Vector Machine Test Set")
plt.xlabel('First Principal Component')
plt.ylabel('Second Principal Component')
plt.legend()
plt.savefig("svm_pci_ts_80_percent.jpeg", format='jpeg', dpi=300, bbox_inches='tight')
plt.show()

# %%
plt.figure(figsize=(15,10))
models = [
{
    'label': 'Logistic Regression',
    'model': lr,
},
{
    'label': 'Decision Tree',
    'model': dt,
},
{
    'label': 'Bagging Decision Tree',
    'model': dtree,
},
{
    'label': 'Stochastic Gradient Descent Classifier',
    'model': sgd,
},
{
    'label': 'Support Vector Machine',
    'model': svm,
},
]
for m in models:
    model = m['model'] 
    model.fit(X_train_pca, y_train) 
    y_pred=model.predict(X_test_pca) 
    fpr, tpr, thresholds = roc_curve(y_test, model.predict_proba(X_test_pca)[:,1])
    auc = roc_auc_score(y_test,model.predict(X_test_pca))
    plt.plot(fpr, tpr, label='%s ROC (area = %0.1f)' % (m['label'], auc))

plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('1 - Specificity (False Positive Rate)', fontsize=10)
plt.ylabel('Sensitivity (True Positive Rate)', fontsize=10)
plt.title('Receiver Operating Characteristic (ROC)', fontsize=10)
plt.legend(loc="lower right", fontsize=10)
plt.savefig("roc.jpeg", format='jpeg', dpi=300, bbox_inches='tight')
plt.show()
